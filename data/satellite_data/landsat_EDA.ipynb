# %%
import pandas as pd
df = pd.read_csv('/Users/maxsonntag/Downloads/LANDSAT_ARD_TILE_C2.csv')

# %%
df.shape
# Out:
# (2187048, 25)

# %%
df.head()
# Out:
#    Ard_Version                            Entity_ID     Fill  \
# 0            2  LC08_CU_000009_20201231_20210504_02  99.8786
# 1            2  LC08_CU_000010_20201231_20210504_02  85.9907
# 2            2  LC08_CU_001008_20201231_20210504_02  78.7794
# 3            2  LC08_CU_001009_20201231_20210504_02  24.1403
# 4            2  LC08_CU_001010_20201231_20210504_02   8.4108
#
#    Collection_Number  Scene_Count  Tile_Grid_Horizontal Tile_Grid_Region  \
# 0                  2            1                     0               CU
# 1                  2            1                     0               CU
# 2                  2            2                     1               CU
# 3                  2            2                     1               CU
# 4                  2            2                     1               CU
#
#    Tile_Grid_Vertical                      Tile_Identifier  \
# 0                   9  LC08_CU_000009_20201231_20210504_02
# ...

# %%
df[(df['lowerLeftCornerLatitude'] > 46) & (df['lowerLeftCornerLatitude'] < 46.3) & (df['dateUpdated'] == '2021-08-27')]
# Out:
#          Ard_Version                            Entity_ID     Fill  \
# 66                 2  LC08_CU_017004_20201231_20210504_02  33.0712
# 76                 2  LC08_CU_018004_20201231_20210504_02  38.3302
# 90                 2  LC08_CU_030002_20201231_20210504_02   0.0000
# 250                2  LE07_CU_016004_20201230_20210504_02  69.9915
# 257                2  LE07_CU_017004_20201230_20210504_02  70.3971
# ...              ...                                  ...      ...
# 2186827            2  LC08_CU_018004_20210102_20210504_02  90.3899
# 2186911            2  LE07_CU_026003_20210102_20210504_02  90.9412
# 2187030            2  LE07_CU_017004_20210101_20210504_02  98.5679
# 2187032            2  LE07_CU_018004_20210101_20210504_02  49.4288
# 2187037            2  LE07_CU_030002_20210101_20210504_02  61.6517
#
#          Collection_Number  Scene_Count  Tile_Grid_Horizontal  \
# 66                       2            2                    17
# ...

# %%
df['Tile_Production_Date'].sort_values()
# Out:
# 1737542    2021/04/21
# 1742463    2021/04/21
# 1742464    2021/04/21
# 1742465    2021/04/21
# 1742466    2021/04/21
#               ...
# 1243218    2024/11/08
# 1243219    2024/11/08
# 1243220    2024/11/08
# 1242814    2024/11/08
# 1242660    2024/11/08
# Name: Tile_Production_Date, Length: 2187048, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2187048 entries, 0 to 2187047
# Data columns (total 25 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Ard_Version                int64
#  1   Entity_ID                  object
#  2   Fill                       float64
#  3   Collection_Number          int64
#  4   Scene_Count                int64
#  5   Tile_Grid_Horizontal       int64
#  6   Tile_Grid_Region           object
#  7   Tile_Grid_Vertical         int64
#  8   Tile_Identifier            object
#  9   Tile_Production_Date       object
#  10  acquisitionDate            object
#  11  browseAvailable            object
#  12  browseURL                  object
#  13  cartURL                    object
#  14  cloudCover                 float64
#  15  dateUpdated                object
#  16  lowerLeftCornerLatitude    float64
#  17  lowerLeftCornerLongitude   float64
#  18  lowerRightCornerLatitude   float64
# ...

# %%
df.isna().sum()
# Out:
# Ard_Version                  0
# Entity_ID                    0
# Fill                         0
# Collection_Number            0
# Scene_Count                  0
# Tile_Grid_Horizontal         0
# Tile_Grid_Region             0
# Tile_Grid_Vertical           0
# Tile_Identifier              0
# Tile_Production_Date         0
# acquisitionDate              0
# browseAvailable              0
# browseURL                    0
# cartURL                      0
# cloudCover                   0
# dateUpdated                  0
# lowerLeftCornerLatitude      0
# lowerLeftCornerLongitude     0
# lowerRightCornerLatitude     0
# lowerRightCornerLongitude    0
# sensor                       0
# upperLeftCornerLatitude      0
# upperLeftCornerLongitude     0
# upperRightCornerLatitude     0
# upperRightCornerLongitude    0
# dtype: int64
